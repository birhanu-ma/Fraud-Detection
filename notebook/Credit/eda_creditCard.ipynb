# %%
import pandas as pd
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)
from src.Credit.data_profiling import DataProfiling
from src.Credit.eda_analysis import ImportantFeaturesEDA

# %%
df =pd.read_csv("../../data/Credit/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Assuming your df is loaded
# df = pd.read_csv('creditcard.csv')

profiler = DataProfiling(df)
processed_df = profiler.run_all()
# Out:
# ====== DATA OVERVIEW ======
# Total Transactions: 284807
# Total Features: 31
#
# Data Types Summary:
# float64    30
# int64       1
# Name: count, dtype: int64
#
# First 3 Rows:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# ...

# %%
processed_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
# This shows you all the rows that are marked as duplicates
duplicate_rows = df[df.duplicated(keep=False)]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
eda = ImportantFeaturesEDA(df, target='Class')
eda.run_all()
# Out:
# === Class Imbalance Quantification ===
#         Count  Percentage (%)
# Class
# 0      283253        99.83329
# 1         473         0.16671
# c:\Users\Birhanu Matebe\Downloads\KAIM\Fraud-Detection\Fraud-Detection\src\Credit\eda_analysis.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x='label', palette='viridis')
# === Distribution of Time and Amount ===
# c:\Users\Birhanu Matebe\Downloads\KAIM\Fraud-Detection\Fraud-Detection\src\Credit\eda_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='label', y=col, data=self.df, ax=axes[i], palette='Set2')
# ...

# %%
# Cleaning the strongest features first
df_cleaned = eda.remove_outliers(features=['V17', 'V14', 'V12', 'V10'], threshold=3.0)
# Out:
# === Removing Outliers for: ['V17', 'V14', 'V12', 'V10'] ===
# Feature V17: Dropped 0 rows.
# Feature V14: Dropped 0 rows.
# Feature V12: Dropped 0 rows.
# Feature V10: Dropped 0 rows.
# Total rows removed: 0

# %%
df_cleaned .to_csv('../../data/Credit/cleaned_creditcard_data.csv', index=False)
