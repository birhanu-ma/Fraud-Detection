# %%
import pandas as pd
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)
from src.feature_engineering import FraudDataProcessor

# %%
df =pd.read_csv("../data/cleaned_data.csv")

# %%
df.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0   247547  2015-06-28 03:00:34  2015-08-09 03:57:29              47
# 1   220737  2015-01-28 14:21:11  2015-02-11 20:28:28              15
# 2   390400  2015-03-19 20:49:09  2015-04-11 23:41:23              44
# 3    69592  2015-02-24 06:11:57  2015-05-23 16:40:14              55
# 4   174987  2015-07-07 12:58:11  2015-11-03 04:04:30              51
#
#        device_id  source browser sex  age  ip_address  class    country
# 0  KIXYSVCHIPQBR     SEO  Safari   F   30    16778864      0  Australia
# 1  PKYOWQKWGJNJI     SEO  Chrome   F   34    16842045      0   Thailand
# 2  LVCSXLISZHVUO     Ads      IE   M   29    16843656      0      China
# 3  UHAUHNXXUADJE  Direct  Chrome   F   30    16938732      0      China
# 4  XPGPMOHIDRMGE     SEO  Chrome   F   37    16971984      0   Thailand

# %%
 # Initialize processor
processor = FraudDataProcessor(df)

# Feature Engineering
df_fe = processor.feature_engineering()

# Specify features
numerical_features = ['purchase_value', 'time_since_signup', 'transaction_count', 'age', 'hour_of_day', 'day_of_week']
categorical_features = ['device_id', 'source', 'browser', 'sex', 'country']

# Data Transformation
df_transformed = processor.data_transformation(numerical_features, categorical_features)

# Handle class imbalance
X_res, y_res = processor.handle_class_imbalance('class')
# Out:
# Class distribution BEFORE SMOTE: Counter({0: 116878, 1: 12268})
# Class distribution AFTER SMOTE: Counter({0: 116878, 1: 116878})
